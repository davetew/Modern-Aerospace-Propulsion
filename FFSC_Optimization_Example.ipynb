# %%
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
from modern_aerospace_propulsion.ffsc_nozzle.cycle import optimize_ffsc_design

print("Modules imported successfully")
print("Note: Requires Cantera, CoolProp, and scipy to be installed")
# Out:
# Modules imported successfully
# Note: Requires Cantera, CoolProp, and scipy to be installed

# %% [markdown]
# ## Example 1: Optimize CH4/O2 Engine for Vacuum Operation
#
# Design a 500 kN thrust methalox engine for vacuum operation (e.g., upper stage).

# %%
# Optimize CH4/O2 engine for vacuum
result_vac = optimize_ffsc_design(
    F_vac=500e3,  # 500 kN thrust
    fuel_name="CH4",
    ox_name="O2",
    fuel_coolprop="Methane",
    ox_coolprop="Oxygen",
    T_fuel_tank=110.0,  # K (saturated liquid CH4)
    T_ox_tank=90.0,     # K (saturated liquid O2)
    p_amb=0.0,          # Vacuum
    T_wall_max_limit=900.0,  # K (copper limit)
    # Bounds for optimization (moderately wide for first attempt)
    p0_bounds=(1e5, 100e6),      # 15-30 MPa chamber pressure
    OF_bounds=(2.0, 4.0),         # O/F ratio range
    r_t_bounds=(0.02, 0.15),      # 80-150 mm throat radius
    eps_bounds=(5.0, 35.0),      # Expansion ratio 15-35
    L_noz_bounds=(0.5, 2.5),      # 1.0-2.5 m nozzle length
    coolant_frac_bounds=(0.1, 0.5),  # 15-45% coolant flow
    # Better initial guess based on typical methalox engines
    initial_guess={
        'p0': 22e6,
        'OF': 3.3,
        'r_t': 0.10,
        'eps': 25.0,
        'L_noz': 1.8,
        'coolant_frac': 0.25,
    },
    # Turbomachinery efficiencies
    eta_pump_fuel=0.70,
    eta_pump_ox=0.70,
    eta_turb_fuel=0.90,
    eta_turb_ox=0.90,
    eta_mech=0.98,
    # Optimizer settings (increased iterations for robustness)
    #optimizer_method="SLSQP",
    optimizer_method="trust-constr",
    max_iterations=400,  # Increased from 100
    verbose=True,
)
# Out:
# ======================================================================
# Starting FFSC Design Optimization
# ======================================================================
# Target thrust: 500.0 kN
# Propellants: CH4/O2
# Tank temps: T_fuel=110.0 K, T_ox=90.0 K
# Ambient pressure: 0.0 kPa
# Wall temp limit: 900.0 K
#
# Bounds:
#   p0:           0.1 - 100.0 MPa
#   OF:           2.00 - 4.00
#   r_t:          20.0 - 150.0 mm
#   eps:          5.0 - 35.0
#   L_noz:        0.50 - 2.50 m
#   coolant_frac: 10.0% - 50.0%
#
# Initial guess:
#   p0=22.0 MPa, OF=3.30, r_t=100.0 mm, eps=25.0, L_noz=1.80 m, coolant_frac=25.0%
#
# --- Testing initial guess ---
#   Eval   1: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
# ⚠ WARNING: Initial guess produced invalid result (obj=1.00e+06)
#   This may indicate a problem with input parameters or bounds.
#   Attempting optimization anyway...
#
# ======================================================================
#
#   Eval   2: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval   3: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval   4: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval   5: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval   6: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval   7: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval   8: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval   9: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  10: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  11: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  12: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  13: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  14: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  15: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
# /Users/davidtew/anaconda3/envs/aviation/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:376: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(self.x - self.x_prev, self.g - self.g_prev)
# /Users/davidtew/anaconda3/envs/aviation/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:728: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(delta_x, delta_g)
#   Eval  16: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  17: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  18: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  19: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  20: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  21: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  22: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  23: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  24: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  25: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  26: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  27: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  28: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  29: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  30: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  31: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  32: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  33: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  34: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  35: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  36: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  37: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  38: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  39: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  40: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  41: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  42: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  43: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  44: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  45: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  46: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  47: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  48: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  49: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  50: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  51: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  52: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  53: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  54: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  55: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  56: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  57: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  58: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  59: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  60: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  61: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  62: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  63: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  64: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  65: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  66: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  67: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  68: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  69: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  70: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  71: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  72: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  73: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  74: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  75: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  76: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  77: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  78: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  79: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  80: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  81: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  82: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  83: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  84: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  85: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  86: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  87: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  88: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  89: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  90: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  91: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  92: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  93: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  94: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  95: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  96: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  97: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  98: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval  99: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 100: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 101: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 102: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 103: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 104: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 105: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 106: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 107: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 108: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 109: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 110: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 111: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 112: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 113: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 114: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 115: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 116: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 117: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 118: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 119: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 120: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 121: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 122: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 123: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 124: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 125: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 126: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 127: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 128: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 129: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 130: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 131: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 132: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 133: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 134: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 135: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 136: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 137: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 138: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 139: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 140: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 141: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 142: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 143: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 144: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 145: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 146: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 147: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 148: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 149: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 150: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 151: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 152: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 153: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 154: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 155: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 156: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 157: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 158: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 159: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 160: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 161: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 162: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 163: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 164: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 165: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 166: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 167: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 168: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 169: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 170: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 171: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 172: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 173: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 174: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 175: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 176: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 177: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 178: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 179: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 180: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 181: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 182: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 183: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 184: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 185: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 186: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 187: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 188: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 189: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 190: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 191: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 192: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 193: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 194: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 195: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 196: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 197: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 198: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 199: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 200: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 201: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 202: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 203: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 204: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 205: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 206: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 207: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 208: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 209: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 210: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 211: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 212: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 213: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 214: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 215: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 216: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 217: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 218: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 219: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 220: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 221: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 222: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 223: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 224: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 225: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 226: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 227: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 228: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 229: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 230: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 231: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 232: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 233: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 234: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 235: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 236: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 237: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 238: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 239: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 240: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 241: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 242: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 243: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 244: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 245: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 246: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 247: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 248: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 249: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 250: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 251: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 252: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 253: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 254: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 255: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 256: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 257: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 258: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 259: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 260: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 261: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 262: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 263: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 264: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 265: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 266: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 267: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 268: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 269: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 270: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 271: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 272: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 273: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 274: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 275: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 276: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 277: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 278: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 279: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 280: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 281: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 282: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 283: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 284: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 285: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 286: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 287: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 288: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 289: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 290: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 291: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 292: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 293: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 294: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 295: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 296: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 297: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 298: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 299: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 300: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 301: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 302: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 303: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 304: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 305: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 306: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 307: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 308: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 309: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 310: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 311: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 312: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 313: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 314: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 315: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 316: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 317: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 318: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 319: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 320: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 321: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 322: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 323: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 324: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 325: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 326: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 327: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 328: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 329: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 330: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 331: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 332: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 333: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 334: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 335: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 336: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 337: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 338: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 339: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 340: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 341: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 342: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 343: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 344: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 345: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 346: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 347: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 348: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 349: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 350: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 351: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 352: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 353: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 354: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 355: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 356: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 357: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 358: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 359: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 360: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 361: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 362: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 363: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 364: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 365: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 366: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 367: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 368: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 369: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 370: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 371: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 372: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 373: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 374: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 375: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 376: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 377: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 378: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 379: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 380: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 381: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 382: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 383: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 384: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 385: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 386: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 387: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 388: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 389: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 390: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 391: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 392: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 393: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 394: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 395: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 396: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 397: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 398: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 399: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 400: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 401: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 402: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 403: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 404: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 405: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 406: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 407: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 408: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 409: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 410: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 411: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 412: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 413: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 414: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 415: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 416: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 417: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 418: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 419: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 420: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 421: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 422: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 423: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 424: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 425: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 426: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 427: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 428: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 429: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 430: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 431: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 432: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 433: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 434: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 435: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 436: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 437: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 438: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 439: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 440: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 441: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 442: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 443: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 444: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 445: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 446: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 447: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 448: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 449: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 450: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 451: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 452: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 453: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 454: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 455: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 456: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 457: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 458: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 459: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 460: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 461: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 462: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 463: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 464: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 465: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 466: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 467: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 468: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 469: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 470: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 471: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 472: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 473: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 474: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 475: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 476: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 477: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 478: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 479: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 480: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 481: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 482: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 483: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
# ...
#   Eval 983: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 984: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 985: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 986: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 987: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 988: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 989: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 990: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 991: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 992: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 993: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 994: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 995: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 996: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 997: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 998: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 999: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1000: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1001: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1002: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1003: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1004: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1005: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1006: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1007: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1008: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1009: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1010: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1011: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1012: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1013: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1014: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1015: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1016: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1017: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1018: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1019: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1020: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1021: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1022: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1023: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1024: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1025: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1026: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1027: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1028: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1029: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1030: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1031: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1032: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1033: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1034: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1035: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1036: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1037: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1038: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1039: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1040: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1041: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1042: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1043: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1044: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1045: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1046: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1047: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1048: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1049: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1050: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1051: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1052: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1053: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1054: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1055: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1056: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1057: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1058: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1059: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1060: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1061: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1062: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1063: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1064: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1065: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1066: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1067: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1068: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1069: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1070: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1071: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1072: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1073: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1074: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1075: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1076: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1077: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1078: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1079: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1080: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1081: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1082: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1083: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1084: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1085: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1086: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1087: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1088: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1089: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1090: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1091: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1092: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1093: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1094: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1095: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1096: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1097: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1098: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1099: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1100: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1101: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1102: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1103: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1104: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1105: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1106: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1107: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1108: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1109: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1110: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1111: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1112: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1113: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1114: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1115: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1116: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1117: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1118: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1119: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1120: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1121: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1122: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1123: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1124: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1125: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1126: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1127: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
#   Eval 1128: ✗ FAILED - ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the r
# Constraint violation exceeds 'gtol'
# Number of iterations: 362, function evaluations: 1127, CG iterations: 350, optimality: 2.20e-10, constraint violation: 1.00e+09, execution time: 3e+02 s.
#
# ======================================================================
# Optimization Complete - FAILED TO CONVERGE
# ======================================================================
#
# Message: Constraint violation exceeds 'gtol'
# Function evaluations: 1127
# Iterations: 362
#
# ⚠ ERRORS ENCOUNTERED (1 unique types):
#
#   Error 1 (eval 1):
#     ValueError: Inputs in Brent [0.000000,30417.384000] do not bracket the root.  Function value
#     Parameters: p0=22.00 MPa, OF=3.30, r_t=100.0 mm, eps=25.0, L=1.80 m, cool=25.0%
#
#   Common causes:
#     - Thermodynamic properties out of range (check tank temperatures)
#     - CoolProp fluid name mismatch (fuel_coolprop/ox_coolprop)
#     - Cantera species name mismatch (fuel_name/ox_name)
#     - Extreme parameter combinations causing numerical issues
#
# Best result found during search:
#   ✗ No valid solutions found - ALL evaluations failed!
#
#   DIAGNOSIS:
#     ALL function evaluations returned errors or invalid Isp.
#     This typically means:
#       1. Input parameters are fundamentally incompatible
#       2. Bounds are outside feasible design space
#       3. Tank temperatures don't match propellant expectations
#       4. CoolProp/Cantera species names are incorrect
#
#   SUGGESTIONS:
#     - Verify fuel_coolprop='Methane' is valid for CoolProp
#     - Verify ox_coolprop='Oxygen' is valid for CoolProp
#     - Verify fuel_name='CH4' exists in Cantera gas.yaml
#     - Verify ox_name='O2' exists in Cantera gas.yaml
#     - Check tank temps: T_fuel=110.0K, T_ox=90.0K
#     - Try wider bounds or different initial guess
# ======================================================================

# %%
# Extract and display optimal results
if result_vac['success']:
    print("\n" + "="*70)
    print("OPTIMAL VACUUM ENGINE DESIGN")
    print("="*70)
    print(f"\nObjective:")
    print(f"  Maximum Isp:       {result_vac['Isp_opt']:.2f} s")
    print(f"\nOptimal Parameters:")
    print(f"  Chamber pressure:  {result_vac['p0_opt']/1e6:.2f} MPa")
    print(f"  O/F ratio:         {result_vac['OF_opt']:.3f}")
    print(f"  Throat radius:     {result_vac['r_t_opt']*1000:.2f} mm")
    print(f"  Expansion ratio:   {result_vac['eps_opt']:.2f}")
    print(f"  Nozzle length:     {result_vac['L_noz_opt']:.3f} m")
    print(f"  Coolant fraction:  {result_vac['coolant_frac_opt']*100:.1f}%")
    print(f"\nPerformance:")
    print(f"  Vacuum thrust:     {result_vac['F_vac']/1e3:.1f} kN")
    print(f"  Total flow:        {result_vac['m_dot_total']:.2f} kg/s")
    print(f"  Fuel flow:         {result_vac['cycle_results']['m_dot_fuel']:.2f} kg/s")
    print(f"  Oxidizer flow:     {result_vac['cycle_results']['m_dot_ox']:.2f} kg/s")
    print(f"\nFeasibility:")
    print(f"  Fuel turbopump:    {'✓ OK' if result_vac['cycle_results']['fuel_side_ok'] else '✗ FAIL'}")
    print(f"  Ox turbopump:      {'✓ OK' if result_vac['cycle_results']['ox_side_ok'] else '✗ FAIL'}")
    print(f"  Max wall temp:     {result_vac['cycle_results']['T_wall_max']:.1f} K")
    print(f"  Coolant used:      {result_vac['cycle_results']['coolant_fraction']*100:.1f}%")
else:
    print("\n" + "="*70)
    print("OPTIMIZATION DID NOT CONVERGE")
    print("="*70)
    print(f"Message: {result_vac['message']}")
    print(f"\nTroubleshooting suggestions:")
    print(f"1. Increase max_iterations to 250-300")
    print(f"2. Try optimizer_method='trust-constr'")
    print(f"3. Relax T_wall_max_limit to 950 K for initial pass")
    print(f"4. Use staged optimization (see Example 5 below)")
    print(f"5. Check if best result during search was close:")
    if result_vac.get('Isp_opt') is not None:
        print(f"   Best Isp found: {result_vac['Isp_opt']:.2f} s")
# Out:
# ======================================================================
# OPTIMIZATION DID NOT CONVERGE
# ======================================================================
# Message: Positive directional derivative for linesearch
#
# Troubleshooting suggestions:
# 1. Increase max_iterations to 250-300
# 2. Try optimizer_method='trust-constr'
# 3. Relax T_wall_max_limit to 950 K for initial pass
# 4. Use staged optimization (see Example 5 below)
# 5. Check if best result during search was close:
#    Best Isp found: -inf s

# %% [markdown]
# ## Example 2: Optimize CH4/O2 Engine for Sea-Level Operation
#
# Design a 1000 kN thrust methalox engine for sea-level operation (e.g., first stage).

# %%
# Optimize CH4/O2 engine for sea level
result_sl = optimize_ffsc_design(
    F_vac=1000e3,  # 1000 kN thrust (note: vacuum thrust, sea level will be lower)
    fuel_name="CH4",
    ox_name="O2",
    fuel_coolprop="Methane",
    ox_coolprop="Oxygen",
    T_fuel_tank=110.0,  # K
    T_ox_tank=90.0,     # K
    p_amb=101325.0,     # Sea level (1 atm)
    T_wall_max_limit=900.0,  # K
    # Bounds - for sea level, lower expansion ratio is better
    p0_bounds=(15e6, 35e6),      # Higher pressure helps at sea level
    OF_bounds=(2.5, 4.0),
    r_t_bounds=(0.08, 0.25),
    eps_bounds=(10.0, 25.0),     # Lower expansion for sea level
    L_noz_bounds=(0.5, 2.5),
    # Turbomachinery
    eta_pump_fuel=0.70,
    eta_pump_ox=0.70,
    eta_turb_fuel=0.90,
    eta_turb_ox=0.90,
    eta_mech=0.98,
    # Optimizer
    optimizer_method="SLSQP",
    max_iterations=100,
    verbose=True,
)
# Out:
# ======================================================================
# Starting FFSC Design Optimization
# ======================================================================
# Target thrust: 1000.0 kN
# Propellants: CH4/O2
# Tank temps: T_fuel=110.0 K, T_ox=90.0 K
# Ambient pressure: 101.3 kPa
# Wall temp limit: 900.0 K
#
# Initial guess:
#   p0=25.0 MPa, OF=3.25, r_t=165.0 mm, eps=17.5, L_noz=1.50 m, coolant_frac=35.0%
#
# ======================================================================
#
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1000000.0
#             Iterations: 5
#             Function evaluations: 7
#             Gradient evaluations: 1
#
# ======================================================================
# Optimization Complete - FAILED TO CONVERGE
# ======================================================================
# Message: Positive directional derivative for linesearch
# Returning best result found during search:
# ======================================================================

# %%
# Display sea-level optimal results
if result_sl['success']:
    print("\n" + "="*70)
    print("OPTIMAL SEA-LEVEL ENGINE DESIGN")
    print("="*70)
    print(f"\nObjective:")
    print(f"  Maximum Isp (SL): {result_sl['Isp_opt']:.2f} s")
    print(f"\nOptimal Parameters:")
    print(f"  Chamber pressure:  {result_sl['p0_opt']/1e6:.2f} MPa")
    print(f"  O/F ratio:         {result_sl['OF_opt']:.3f}")
    print(f"  Throat radius:     {result_sl['r_t_opt']*1000:.2f} mm")
    print(f"  Expansion ratio:   {result_sl['eps_opt']:.2f}")
    print(f"  Nozzle length:     {result_sl['L_noz_opt']:.3f} m")
    print(f"\nNote: Lower expansion ratio compared to vacuum design")
    print(f"      (avoids over-expansion and flow separation at sea level)")

# %% [markdown]
# ## Example 3: Compare Vacuum vs. Sea-Level Designs

# %%
# Create comparison table
if result_vac['success'] and result_sl['success']:
    import pandas as pd
    
    comparison = pd.DataFrame({
        'Parameter': [
            'Chamber Pressure (MPa)',
            'O/F Ratio',
            'Throat Radius (mm)',
            'Expansion Ratio',
            'Nozzle Length (m)',
            'Isp (s)',
            'Total Flow (kg/s)',
        ],
        'Vacuum Design': [
            f"{result_vac['p0_opt']/1e6:.2f}",
            f"{result_vac['OF_opt']:.3f}",
            f"{result_vac['r_t_opt']*1000:.2f}",
            f"{result_vac['eps_opt']:.2f}",
            f"{result_vac['L_noz_opt']:.3f}",
            f"{result_vac['Isp_opt']:.2f}",
            f"{result_vac['m_dot_total']:.2f}",
        ],
        'Sea-Level Design': [
            f"{result_sl['p0_opt']/1e6:.2f}",
            f"{result_sl['OF_opt']:.3f}",
            f"{result_sl['r_t_opt']*1000:.2f}",
            f"{result_sl['eps_opt']:.2f}",
            f"{result_sl['L_noz_opt']:.3f}",
            f"{result_sl['Isp_opt']:.2f}",
            f"{result_sl['m_dot_total']:.2f}",
        ]
    })
    
    print("\n" + "="*70)
    print("VACUUM vs SEA-LEVEL DESIGN COMPARISON")
    print("="*70)
    print(comparison.to_string(index=False))
    print("\nKey Observations:")
    print("  • Sea-level design has lower expansion ratio (avoids separation)")
    print("  • Sea-level design may use higher chamber pressure")
    print("  • Vacuum design achieves higher Isp due to better expansion")

# %% [markdown]
# ## Example 4: Sensitivity to Initial Guess
#
# Test if the optimizer is robust to different starting points.

# %%
# Try optimization with different initial guesses
initial_guesses = [
    {'p0': 15e6, 'OF': 3.0, 'r_t': 0.10, 'eps': 20.0, 'L_noz': 1.5},
    {'p0': 25e6, 'OF': 3.5, 'r_t': 0.12, 'eps': 25.0, 'L_noz': 2.0},
    {'p0': 20e6, 'OF': 2.8, 'r_t': 0.08, 'eps': 30.0, 'L_noz': 2.5},
]

results_list = []
for i, guess in enumerate(initial_guesses):
    print(f"\n{'='*70}")
    print(f"Trial {i+1}: Initial guess p0={guess['p0']/1e6:.1f} MPa, "
          f"OF={guess['OF']:.2f}, eps={guess['eps']:.1f}")
    print(f"{'='*70}")
    
    result = optimize_ffsc_design(
        F_vac=500e3,
        fuel_name="CH4",
        ox_name="O2",
        fuel_coolprop="Methane",
        ox_coolprop="Oxygen",
        T_fuel_tank=110.0,
        T_ox_tank=90.0,
        p_amb=0.0,
        initial_guess=guess,
        verbose=False,  # Suppress detailed output
    )
    
    results_list.append(result)
    if result['success']:
        print(f"Converged to Isp = {result['Isp_opt']:.2f} s")
    else:
        print(f"Failed to converge: {result['message']}")

# Check if all trials converged to same optimum
if all(r['success'] for r in results_list):
    isp_values = [r['Isp_opt'] for r in results_list]
    print(f"\n{'='*70}")
    print("CONVERGENCE CHECK")
    print(f"{'='*70}")
    print(f"All trials converged successfully")
    print(f"Isp range: {min(isp_values):.2f} - {max(isp_values):.2f} s")
    print(f"Variation: {max(isp_values) - min(isp_values):.3f} s")
    if max(isp_values) - min(isp_values) < 0.5:
        print("✓ Optimizer is robust - all trials found same optimum")
    else:
        print("⚠ Optimizer may have found different local optima")
# Out:
# ======================================================================
# Trial 1: Initial guess p0=15.0 MPa, OF=3.00, eps=20.0
# ======================================================================
# Failed to converge: Positive directional derivative for linesearch
#
# ======================================================================
# Trial 2: Initial guess p0=25.0 MPa, OF=3.50, eps=25.0
# ======================================================================
# Failed to converge: Positive directional derivative for linesearch
#
# ======================================================================
# Trial 3: Initial guess p0=20.0 MPa, OF=2.80, eps=30.0
# ======================================================================
# Failed to converge: Positive directional derivative for linesearch

# %% [markdown]
# ## Notes on Optimization
#
# ### Algorithm Selection
# - **SLSQP** (default): Good for smooth problems with both equality and inequality constraints
# - **trust-constr**: More robust for difficult constraints, but slower
# - **COBYLA**: Derivative-free, good for noisy objectives, but less accurate
#
# ### Typical Results for CH4/O2
# - **Vacuum Isp**: 330-350 s (depending on constraints)
# - **Optimal O/F**: 3.0-3.5 (slightly fuel-rich)
# - **Optimal Chamber Pressure**: 20-30 MPa
# - **Optimal Expansion Ratio**: 25-40 for vacuum, 12-20 for sea level
#
# ### Computational Cost
# - Each function evaluation: ~0.5-2 seconds
# - Typical convergence: 30-80 evaluations
# - Total time: 30-150 seconds per optimization
#
# ### Tips for Success
# 1. Start with reasonable bounds based on propellant properties
# 2. Use tighter bounds if you know the approximate operating regime
# 3. For H2/O2, use wider O/F bounds (4-8) as stoichiometric ratio is higher
# 4. If optimization fails, try relaxing constraints or changing initial guess

# %% [markdown]
# ## Example 5: Improving Convergence
#
# If optimization doesn't converge, try these strategies:
#
# 1. **Increase iterations**: Allow more function evaluations
# 2. **Better initial guess**: Start closer to the optimum
# 3. **Relaxed constraints**: Use slightly looser bounds initially
# 4. **Different optimizer**: Try trust-constr or COBYLA
# 5. **Staged optimization**: Optimize in steps with tighter bounds each time

# %%
# Strategy 1: Increase iterations and use better initial guess
print("Strategy 1: More iterations + better initial guess")
print("="*70)

# Start with a reasonable guess based on typical methalox engines
better_guess = {
    'p0': 22e6,           # ~22 MPa is typical for modern engines
    'OF': 3.3,            # Slightly fuel-rich is common
    'r_t': 0.10,          # Medium throat size
    'eps': 25.0,          # Reasonable vacuum expansion
    'L_noz': 1.8,         # Moderate length
    'coolant_frac': 0.25  # 25% coolant flow typical
}

result_strategy1 = optimize_ffsc_design(
    F_vac=500e3,
    fuel_name="CH4",
    ox_name="O2",
    fuel_coolprop="Methane",
    ox_coolprop="Oxygen",
    T_fuel_tank=110.0,
    T_ox_tank=90.0,
    p_amb=0.0,
    T_wall_max_limit=900.0,
    # More generous bounds
    p0_bounds=(15e6, 30e6),
    OF_bounds=(2.8, 3.8),
    r_t_bounds=(0.08, 0.15),
    eps_bounds=(15.0, 35.0),
    L_noz_bounds=(1.0, 2.5),
    coolant_frac_bounds=(0.15, 0.45),
    # Better initial guess
    initial_guess=better_guess,
    # More iterations
    max_iterations=200,
    optimizer_method="SLSQP",
    verbose=True,
)

if result_strategy1['success']:
    print(f"\n✓ SUCCESS: Isp = {result_strategy1['Isp_opt']:.2f} s")
    print(f"  Coolant fraction: {result_strategy1['coolant_frac_opt']*100:.1f}%")
else:
    print(f"\n✗ Did not converge: {result_strategy1['message']}")
# Out:
# Strategy 1: More iterations + better initial guess
# ======================================================================
#
# ======================================================================
# Starting FFSC Design Optimization
# ======================================================================
# Target thrust: 500.0 kN
# Propellants: CH4/O2
# Tank temps: T_fuel=110.0 K, T_ox=90.0 K
# Ambient pressure: 0.0 kPa
# Wall temp limit: 900.0 K
#
# Initial guess:
#   p0=22.0 MPa, OF=3.30, r_t=100.0 mm, eps=25.0, L_noz=1.80 m, coolant_frac=25.0%
#
# ======================================================================
#
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1000000.0
#             Iterations: 5
#             Function evaluations: 7
#             Gradient evaluations: 1
#
# ======================================================================
# Optimization Complete - FAILED TO CONVERGE
# ======================================================================
# Message: Positive directional derivative for linesearch
# Returning best result found during search:
# ======================================================================
#
#
# ✗ Did not converge: Positive directional derivative for linesearch

# %%
# Strategy 2: Use trust-constr optimizer (more robust for constraints)
print("\n\nStrategy 2: trust-constr optimizer")
print("="*70)
print("Note: trust-constr is slower but handles constraints better")

result_strategy2 = optimize_ffsc_design(
    F_vac=500e3,
    fuel_name="CH4",
    ox_name="O2",
    fuel_coolprop="Methane",
    ox_coolprop="Oxygen",
    T_fuel_tank=110.0,
    T_ox_tank=90.0,
    p_amb=0.0,
    T_wall_max_limit=1500.0,
    p0_bounds=(15e6, 30e6),
    OF_bounds=(2.8, 3.8),
    r_t_bounds=(0.08, 0.15),
    eps_bounds=(15.0, 35.0),
    L_noz_bounds=(1.0, 2.5),
    coolant_frac_bounds=(0.15, 0.45),
    initial_guess=better_guess,
    optimizer_method="trust-constr",  # Different optimizer
    max_iterations=150,
    verbose=True,
)

if result_strategy2['success']:
    print(f"\n✓ SUCCESS: Isp = {result_strategy2['Isp_opt']:.2f} s")
    print(f"  Coolant fraction: {result_strategy2['coolant_frac_opt']*100:.1f}%")
else:
    print(f"\n✗ Did not converge: {result_strategy2['message']}")
# Out:
# Strategy 2: trust-constr optimizer
# ======================================================================
# Note: trust-constr is slower but handles constraints better
#
# ======================================================================
# Starting FFSC Design Optimization
# ======================================================================
# Target thrust: 500.0 kN
# Propellants: CH4/O2
# Tank temps: T_fuel=110.0 K, T_ox=90.0 K
# Ambient pressure: 0.0 kPa
# Wall temp limit: 1500.0 K
#
# Initial guess:
#   p0=22.0 MPa, OF=3.30, r_t=100.0 mm, eps=25.0, L_noz=1.80 m, coolant_frac=25.0%
#
# ======================================================================
#
#   Eval  10: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
# /Users/davidtew/anaconda3/envs/aviation/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:376: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(self.x - self.x_prev, self.g - self.g_prev)
# /Users/davidtew/anaconda3/envs/aviation/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:728: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(delta_x, delta_g)
#   Eval  20: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval  30: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval  40: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval  50: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval  60: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval  70: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval  80: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval  90: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 100: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 110: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 120: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 130: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 140: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 150: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 160: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 170: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 180: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 190: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 200: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 210: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 220: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 230: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 240: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 250: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 260: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 270: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 280: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 290: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 300: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 310: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 320: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 330: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 340: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 350: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 360: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 370: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 380: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 390: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 400: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 410: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 420: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 430: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 440: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 450: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 460: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 470: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 480: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 490: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 500: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 510: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 520: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 530: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 540: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 550: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 560: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 570: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 580: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 590: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 600: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 610: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 620: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 630: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 640: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 650: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 660: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 670: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
#   Eval 680: Analysis failed - Inputs in Brent [0.000000,30417.384000] do not bra
# The maximum number of function evaluations is exceeded.
# Number of iterations: 150, function evaluations: 686, CG iterations: 145, optimality: 2.36e-06, constraint violation: 1.00e+09, execution time: 1.8e+02 s.
#
# ======================================================================
# Optimization Complete - FAILED TO CONVERGE
# ======================================================================
# Message: The maximum number of function evaluations is exceeded.
# Returning best result found during search:
# ======================================================================
#
#
# ✗ Did not converge: The maximum number of function evaluations is exceeded.

# %%
# Strategy 3: Staged optimization (coarse to fine)
print("\n\nStrategy 3: Staged optimization (coarse → fine)")
print("="*70)
print("First pass: Wide bounds, find approximate optimum")

# Stage 1: Wide bounds to find general region
result_stage1 = optimize_ffsc_design(
    F_vac=500e3,
    fuel_name="CH4",
    ox_name="O2",
    fuel_coolprop="Methane",
    ox_coolprop="Oxygen",
    T_fuel_tank=110.0,
    T_ox_tank=90.0,
    p_amb=0.0,
    T_wall_max_limit=950.0,  # Slightly relaxed for first pass
    # Wide bounds
    p0_bounds=(12e6, 32e6),
    OF_bounds=(2.5, 4.0),
    r_t_bounds=(0.07, 0.18),
    eps_bounds=(12.0, 38.0),
    L_noz_bounds=(0.8, 2.8),
    coolant_frac_bounds=(0.12, 0.50),
    optimizer_method="SLSQP",
    max_iterations=100,
    verbose=False,  # Less verbose for first pass
)

if result_stage1['success']:
    print(f"Stage 1 converged: Isp = {result_stage1['Isp_opt']:.2f} s\n")
    
    # Stage 2: Refine around the Stage 1 solution
    print("Second pass: Tighter bounds around Stage 1 optimum")
    
    # Create tighter bounds centered on Stage 1 result
    p0_center = result_stage1['p0_opt']
    OF_center = result_stage1['OF_opt']
    r_t_center = result_stage1['r_t_opt']
    eps_center = result_stage1['eps_opt']
    L_noz_center = result_stage1['L_noz_opt']
    cool_center = result_stage1['coolant_frac_opt']
    
    # ±15% around Stage 1 result
    result_stage2 = optimize_ffsc_design(
        F_vac=500e3,
        fuel_name="CH4",
        ox_name="O2",
        fuel_coolprop="Methane",
        ox_coolprop="Oxygen",
        T_fuel_tank=110.0,
        T_ox_tank=90.0,
        p_amb=0.0,
        T_wall_max_limit=900.0,  # Stricter constraint now
        # Tighter bounds around Stage 1 result
        p0_bounds=(0.85*p0_center, 1.15*p0_center),
        OF_bounds=(0.90*OF_center, 1.10*OF_center),
        r_t_bounds=(0.85*r_t_center, 1.15*r_t_center),
        eps_bounds=(0.85*eps_center, 1.15*eps_center),
        L_noz_bounds=(0.85*L_noz_center, 1.15*L_noz_center),
        coolant_frac_bounds=(0.80*cool_center, min(1.20*cool_center, 0.60)),
        # Use Stage 1 result as initial guess
        initial_guess={
            'p0': p0_center,
            'OF': OF_center,
            'r_t': r_t_center,
            'eps': eps_center,
            'L_noz': L_noz_center,
            'coolant_frac': cool_center,
        },
        optimizer_method="SLSQP",
        max_iterations=100,
        verbose=True,
    )
    
    if result_stage2['success']:
        print(f"\n✓ STAGED OPTIMIZATION SUCCESS")
        print(f"  Final Isp: {result_stage2['Isp_opt']:.2f} s")
        print(f"  Improvement: {result_stage2['Isp_opt'] - result_stage1['Isp_opt']:.2f} s")
        print(f"  Coolant fraction: {result_stage2['coolant_frac_opt']*100:.1f}%")
    else:
        print(f"\n⚠ Stage 2 did not converge, but Stage 1 result available")
        print(f"  Stage 1 Isp: {result_stage1['Isp_opt']:.2f} s")
else:
    print(f"✗ Stage 1 did not converge: {result_stage1['message']}")

# %% [markdown]
# ## Convergence Troubleshooting Guide
#
# ### Common Issues and Solutions:
#
# **1. "Maximum iterations reached"**
# - **Solution**: Increase `max_iterations` to 200-300
# - **Why**: Complex design space needs more exploration
#
# **2. "Positive directional derivative for linesearch"**
# - **Solution**: Try `trust-constr` optimizer instead of SLSQP
# - **Why**: SLSQP can struggle with constraint boundaries
#
# **3. Optimizer stops early with poor Isp**
# - **Solution**: Provide better `initial_guess` closer to expected result
# - **Why**: May be stuck in local minimum
#
# **4. Infeasible constraints**
# - **Solution**: Temporarily relax `T_wall_max_limit` (e.g., 950 K) or widen bounds
# - **Why**: Design space may be too constrained
#
# **5. Oscillating between designs**
# - **Solution**: Use staged optimization (wide → tight bounds)
# - **Why**: Fine-tunes solution after finding approximate region
#
# ### Recommended Settings by Problem:
#
# **Easy problems** (loose constraints, wide feasible region):
# - SLSQP, 100 iterations, default bounds
#
# **Medium problems** (some tight constraints):
# - SLSQP, 150-200 iterations, better initial guess
#
# **Difficult problems** (tight constraints, narrow feasible region):
# - trust-constr, 200 iterations, staged optimization
#
# **Very difficult problems** (highly constrained):
# - Staged optimization with relaxed then tight constraints
# - Multiple random initial guesses to find global optimum
